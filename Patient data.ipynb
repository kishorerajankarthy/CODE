# %% [markdown]
# <a href="https://colab.research.google.com/github/kishorerajankarthy/CODE/blob/main/Patient%20data.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# Load the dataset
df = pd.read_csv("/content/patient_dataset.csv")  # Change filename if needed

# Display first 5 rows
df.head()
# Out:
#    Patient ID           Name  Age  Gender        Disease         Doctor  \
# 0        1000      Revathi S   63  Female         Asthma    Dr. L. Nair
# 1        1001     Arun Kumar   38    Male         Asthma    Dr. L. Nair
# 2        1002  Senthil Kumar   67    Male       Diabetes   Dr. T. Joshi
# 3        1003       Selvam M   10    Male         Asthma    Dr. L. Nair
# 4        1004      Nivedha M   78  Female  Bone Fracture  Dr. D. Khanna
#
#        Specialization Hospital       City
# 0       Pulmonologist     KMCH      Salem
# 1       Pulmonologist     SIMS    Vellore
# 2     Endocrinologist      CMC    Chennai
# 3       Pulmonologist       GH  Thanjavur
# 4  Orthopedic Surgeon   Apollo    Chennai

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3000 entries, 0 to 2999
# Data columns (total 9 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Patient ID      3000 non-null   int64
#  1   Name            3000 non-null   object
#  2   Age             3000 non-null   int64
#  3   Gender          3000 non-null   object
#  4   Disease         3000 non-null   object
#  5   Doctor          3000 non-null   object
#  6   Specialization  3000 non-null   object
#  7   Hospital        3000 non-null   object
#  8   City            3000 non-null   object
# dtypes: int64(2), object(7)
# memory usage: 211.1+ KB

# %%
df.isnull().sum()
# Out:
# Patient ID        0
# Name              0
# Age               0
# Gender            0
# Disease           0
# Doctor            0
# Specialization    0
# Hospital          0
# City              0
# dtype: int64

# %%
df[df['Age'] > 50]
# Out:
#       Patient ID           Name  Age  Gender        Disease         Doctor  \
# 0           1000      Revathi S   63  Female         Asthma    Dr. L. Nair
# 2           1002  Senthil Kumar   67    Male       Diabetes   Dr. T. Joshi
# 4           1004      Nivedha M   78  Female  Bone Fracture  Dr. D. Khanna
# 6           1006      Lavanya R   80  Female           Cold  Dr. A. Sharma
# 8           1008      Bhavani R   78  Female    Eye Problem  Dr. S. Bhatia
# ...          ...            ...  ...     ...            ...            ...
# 2979        3979    Karthikeyan   63  Female           Cold  Dr. A. Sharma
# 2980        3980      Mohan Raj   57    Male          Fever   Dr. R. Verma
# 2985        3985        Divya S   71    Male          Fever   Dr. R. Verma
# 2987        3987      Bhavani R   55  Female           Cold  Dr. A. Sharma
# 2991        3991       Swathi K   56    Male    Eye Problem  Dr. S. Bhatia
#
#           Specialization Hospital        City
# ...

# %%
df.groupby("Disease").count()
# Out:
#                Patient ID  Name  Age  Gender  Doctor  Specialization  \
# Disease
# Arthritis             296   296  296     296     296             296
# Asthma                277   277  277     277     277             277
# Bone Fracture         296   296  296     296     296             296
# Cold                  283   283  283     283     283             283
# Diabetes              303   303  303     303     303             303
# Eye Problem           327   327  327     327     327             327
# Fever                 310   310  310     310     310             310
# Heart Disease         280   280  280     280     280             280
# Hypertension          322   322  322     322     322             322
# Migraine              306   306  306     306     306             306
#
#                Hospital  City
# Disease
# Arthritis           296   296
# Asthma              277   277
# Bone Fracture       296   296
# Cold                283   283
# Diabetes            303   303
# ...

# %%
df.to_csv("/content/processed_patient_data.csv", index=False)
