# %%
import random

# Define the board
def initialize_board():
    return [[' ' for _ in range(3)] for _ in range(3)]

# Print the board
def print_board(board):
    for row in board:
        print('|'.join(row))
        print('-' * 5)

# Check for a win
def check_win(board, player):
    win_conditions = [
        # Horizontal
        [(0, 0), (0, 1), (0, 2)],
        [(1, 0), (1, 1), (1, 2)],
        [(2, 0), (2, 1), (2, 2)],
        # Vertical
        [(0, 0), (1, 0), (2, 0)],
        [(0, 1), (1, 1), (2, 1)],
        [(0, 2), (1, 2), (2, 2)],
        # Diagonal
        [(0, 0), (1, 1), (2, 2)],
        [(0, 2), (1, 1), (2, 0)]
    ]
    return any(all(board[x][y] == player for x, y in condition) for condition in win_conditions)

# Check if the board is full
def is_full(board):
    return all(cell != ' ' for row in board for cell in row)

# Minimax algorithm
def minimax(board, depth, is_maximizing):
    if check_win(board, 'X'):
        return 10 - depth
    if check_win(board, 'O'):
        return depth - 10
    if is_full(board):
        return 0

    if is_maximizing:
        best_score = -float('inf')
        for i in range(3):
            for j in range(3):
                if board[i][j] == ' ':
                    board[i][j] = 'X'
                    score = minimax(board, depth + 1, False)
                    board[i][j] = ' '
                    best_score = max(score, best_score)
        return best_score
    else:
        best_score = float('inf')
        for i in range(3):
            for j in range(3):
                if board[i][j] == ' ':
                    board[i][j] = 'O'
                    score = minimax(board, depth + 1, True)
                    board[i][j] = ' '
                    best_score = min(score, best_score)
        return best_score

# Find the best move
def find_best_move(board):
    best_score = -float('inf')
    move = None
    for i in range(3):
        for j in range(3):
            if board[i][j] == ' ':
                board[i][j] = 'X'
                score = minimax(board, 0, False)
                board[i][j] = ' '
                if score > best_score:
                    best_score = score
                    move = (i, j)
    return move

# Main function to run the game
def play_game():
    board = initialize_board()
    print("Welcome to Tic-Tac-Toe!")
    while True:
        print_board(board)
        if is_full(board):
            print("It's a draw!")
            break

        # Player's move
        row = int(input("Enter row (0, 1, 2): "))
        col = int(input("Enter column (0, 1, 2): "))
        if board[row][col] == ' ':
            board[row][col] = 'O'
        else:
            print("Invalid move. Try again.")
            continue

        if check_win(board, 'O'):
            print_board(board)
            print("You win!")
            break

        if is_full(board):
            print_board(board)
            print("It's a draw!")
            break

        # AI's move
        print("AI is making a move...")
        move = find_best_move(board)
        if move:
            board[move[0]][move[1]] = 'X'
        else:
            print("No moves available. It's a draw!")
            break

        if check_win(board, 'X'):
            print_board(board)
            print("AI wins!")
            break

if __name__ == "__main__":
    play_game()
# Out:
# Welcome to Tic-Tac-Toe!
#  | |
# -----
#  | |
# -----
#  | |
# -----
# Enter row (0, 1, 2): 1
# Enter column (0, 1, 2): 2
# AI is making a move...
#  | |X
# -----
#  | |O
# -----
#  | |
# -----
# Enter row (0, 1, 2): 2
# Enter column (0, 1, 2): 0
# AI is making a move...
# X| |X
# -----
#  | |O
# -----
# O| |
# -----
# Enter row (0, 1, 2): 2
# Enter column (0, 1, 2): 0
# Invalid move. Try again.
# X| |X
# -----
#  | |O
# -----
# O| |
# -----
# Enter row (0, 1, 2): 1
# Enter column (0, 1, 2): 1
# AI is making a move...
# X|X|X
# -----
#  |O|O
# -----
# O| |
# -----
# AI wins!
